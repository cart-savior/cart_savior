# %%
import urllib.request 
import json
import pandas as pd
from pandas.io.json import json_normalize

# %%
item_category_code = [100,200,300,400,500,600]
#(100:식량작물, 200:채소류, 300:특용작물, 400:과일류, 500:축산물, 600:수산물, default:100)

# %%
df_list = []
for i in item_category_code:
    url = "http://www.kamis.or.kr/service/price/xml.do?action=dailyPriceByCategoryList" +\
    "&p_cert_key=bceaf385-9d34-4a75-9c6f-0607eb325485&p_cert_id=pje1740&p_returntype=json" +\
    "&p_product_cls_code=01" +\
    "&p_regday=2020-04-29" +\
    "&p_convert_kg_yn=N" +\
    "&p_item_category_code=" + str(i)
    response = urllib.request.urlopen(url)
    json_str = response.read().decode("utf-8")
    obj = json.loads(json_str)
    df = pd.DataFrame(obj['data']['item'])
    df_list.append(df.iloc[:, :9])

# %%
list(obj)
# Out:
# ['condition', 'data']

# %%
df = pd.DataFrame(obj['data']['item'])

# %%
df.iloc[:,:9]
# Out:
#    item_name item_code      kind_name kind_code rank rank_code  unit  \
# 0        고등어       611        냉동(1마리)        02   중품        05   1마리
# 1        고등어       611        염장(2마리)        03   중품        05   2마리
# 2         꽁치       612    냉동(수입)(5마리)        01   중품        05   5마리
# 3         갈치       613        냉동(1마리)        02   중품        05   1마리
# 4         명태       615        냉동(1마리)        02   중품        05   1마리
# 5       물오징어       619        냉동(1마리)        02   중품        05   1마리
# 6        건멸치       638      건멸치(100g)        00   중품        05  100g
# 7       건오징어       640     건오징어(10마리)        00   중품        05  10마리
# 8          김       641       마른김(10장)        00   중품        05   10장
# 9          김       641      얼구운김(10장)        01   중품        05   10장
# 10       건미역       642      건미역(100g)        00   상품        04  100g
# 11      수입조기       649  부세수입(냉동)(1마리)        04   중품        05   1마리
# 12       새우젓       650       새우젓(1kg)        00   상품        04   1kg
# 13      멸치액젓       651      멸치액젓(1kg)        00   상품        04   1kg
# 14      굵은소금       652      굵은소금(5kg)        00   상품        04   5kg
# 15        전복       653        전복(5마리)        00   중품        05   5마리
# 16        새우       654  흰다리(수입)(10마리)        01   중품        05  10마리
#
#           day1    dpr1
# 0   당일 (04/29)   2,774
# 1   당일 (04/29)   3,250
# 2   당일 (04/29)   3,548
# 3   당일 (04/29)   6,686
# 4   당일 (04/29)   2,605
# 5   당일 (04/29)   4,035
# 6   당일 (04/29)   2,744
# 7   당일 (04/29)  64,487
# 8   당일 (04/29)     866
# 9   당일 (04/29)   1,485
# 10  당일 (04/29)   2,767
# 11  당일 (04/29)   3,956
# 12  당일 (04/29)  21,068
# 13  당일 (04/29)   4,942
# 14  당일 (04/29)   7,648
# 15  당일 (04/29)  15,620
# 16  당일 (04/29)   4,508

# %%
pd.set_option('max_columns', None)
pd.set_option("max_rows", None)

# %%
data0429 = pd.concat(df_list)

# %%
data0429
# Out:
#    item_name item_code       kind_name kind_code rank rank_code  unit  \
# 0          쌀       111       일반계(20kg)        01   상품        04  20kg
# 1         찹쌀       112        일반계(1kg)        01   상품        04   1kg
# 2          콩       141   흰 콩(국산)(500g)        01   상품        04  500g
# 3          콩       141   흰 콩(국산)(500g)        01   중품        05  500g
# 4          팥       142  붉은 팥(국산)(500g)        00   상품        04  500g
# ..       ...       ...             ...       ...  ...       ...   ...
# 12       새우젓       650        새우젓(1kg)        00   상품        04   1kg
# 13      멸치액젓       651       멸치액젓(1kg)        00   상품        04   1kg
# 14      굵은소금       652       굵은소금(5kg)        00   상품        04   5kg
# 15        전복       653         전복(5마리)        00   중품        05   5마리
# 16        새우       654   흰다리(수입)(10마리)        01   중품        05  10마리
#
#           day1    dpr1
# 0   당일 (04/29)  51,560
# 1   당일 (04/29)   4,663
# 2   당일 (04/29)   4,678
# 3   당일 (04/29)   3,207
# 4   당일 (04/29)   7,797
# ..         ...     ...
# 12  당일 (04/29)  21,068
# 13  당일 (04/29)   4,942
# 14  당일 (04/29)   7,648
# 15  당일 (04/29)  15,620
# 16  당일 (04/29)   4,508
#
# [148 rows x 9 columns]

# %%
data0429['item_name'].unique()
# Out:
# array(['쌀', '찹쌀', '콩', '팥', '녹두', '고구마', '감자', '배추', '양배추', '시금치', '상추',
#        '얼갈이배추', '수박', '참외', '오이', '호박', '토마토', '딸기', '무', '당근', '열무',
#        '건고추', '풋고추', '붉은고추', '양파', '파', '생강', '고춧가루', '미나리', '깻잎', '피망',
#        '파프리카', '멜론', '깐마늘(국산)', '방울토마토', '참깨', '땅콩', '느타리버섯', '팽이버섯',
#        '새송이버섯', '호두', '아몬드', '사과', '배', '포도', '바나나', '참다래', '파인애플', '오렌지',
#        '레몬', '건포도', '건블루베리', '망고', '쇠고기', '돼지고기', '닭고기', '계란', '우유',
#        '고등어', '꽁치', '갈치', '명태', '물오징어', '건멸치', '건오징어', '김', '건미역', '수입조기',
#        '새우젓', '멸치액젓', '굵은소금', '전복', '새우'], dtype=object)

# %%
data_for_image = data0420.loc[:, ['item_name', 'item_code']]

# %%
data_for_image
# Out:
#    item_name item_code
# 0          쌀       111
# 1         찹쌀       112
# 2          콩       141
# 3          콩       141
# 4          팥       142
# 5          팥       142
# 6         녹두       143
# 7         녹두       143
# 8        고구마       151
# 9        고구마       151
# 10        감자       152
# 11        감자       152
# 0         배추       211
# 1         배추       211
# 2        양배추       212
# 3        양배추       212
# 4        시금치       213
# 5         상추       214
# 6         상추       214
# 7         상추       214
# 8         상추       214
# 9      얼갈이배추       215
# 10        수박       221
# 11        수박       221
# 12        참외       222
# 13        참외       222
# 14        오이       223
# 15        오이       223
# 16        오이       223
# 17        오이       223
# 18        호박       224
# 19        호박       224
# 20        호박       224
# 21       토마토       225
# 22       토마토       225
# 23        딸기       226
# 24        딸기       226
# 25         무       231
# 26         무       231
# 27        당근       232
# 28        당근       232
# 29        열무       233
# 30       건고추       241
# 31       건고추       241
# 32       건고추       241
# 33       건고추       241
# 34       풋고추       242
# 35       풋고추       242
# 36       풋고추       242
# 37       풋고추       242
# 38       풋고추       242
# 39       풋고추       242
# 40      붉은고추       243
# 41      붉은고추       243
# 42        양파       245
# 43        양파       245
# 44        양파       245
# 45        양파       245
# 46         파       246
# 47         파       246
# 48         파       246
# 49         파       246
# 50        생강       247
# 51        생강       247
# 52      고춧가루       248
# 53      고춧가루       248
# 54       미나리       252
# 55        깻잎       253
# 56        깻잎       253
# 57        피망       255
# 58        피망       255
# 59      파프리카       256
# 60      파프리카       256
# 61        멜론       257
# 62   깐마늘(국산)       258
# 63   깐마늘(국산)       258
# 64     방울토마토       422
# 65     방울토마토       422
# 0         참깨       312
# 1         참깨       312
# 2         참깨       312
# 3         참깨       312
# 4         땅콩       314
# 5         땅콩       314
# 6      느타리버섯       315
# 7      느타리버섯       315
# 8      느타리버섯       315
# 9      느타리버섯       315
# 10      팽이버섯       316
# 11      팽이버섯       316
# 12     새송이버섯       317
# 13     새송이버섯       317
# 14        호두       318
# 15       아몬드       319
# 0         사과       411
# 1         사과       411
# 2          배       412
# 3          배       412
# 4        바나나       418
# 5        바나나       418
# 6        참다래       419
# 7        참다래       419
# 8       파인애플       420
# 9       파인애플       420
# 10       오렌지       421
# 11        레몬       424
# 12        레몬       424
# 13       건포도       426
# 14     건블루베리       427
# 15        망고       428
# 16        망고       428
# 0        쇠고기       512
# 1        쇠고기       512
# 2        쇠고기       512
# 3        쇠고기       512
# 4        쇠고기       512
# 5        쇠고기       512
# 6        쇠고기       512
# 7        쇠고기       512
# 8        쇠고기       512
# 9        쇠고기       512
# 10       쇠고기       512
# 11       쇠고기       512
# 12      돼지고기       514
# 13      돼지고기       514
# 14      돼지고기       514
# 15      돼지고기       514
# 16      돼지고기       514
# 17       닭고기       515
# 18        계란       516
# 19        우유       535
# 0        고등어       611
# 1        고등어       611
# 2        고등어       611
# 3         꽁치       612
# 4         갈치       613
# 5         명태       615
# 6       물오징어       619
# 7       물오징어       619
# 8        건멸치       638
# 9       건오징어       640
# 10         김       641
# 11         김       641
# 12       건미역       642
# 13         굴       644
# 14      수입조기       649
# 15       새우젓       650
# 16      멸치액젓       651
# 17      굵은소금       652
# 18        전복       653
# 19        새우       654

# %%
data_for_image = data_for_image.reset_index()

# %%
data_for_image = data_for_image.drop('index', axis=1)

# %%
data_for_image = data_for_image.drop_duplicates()

# %%
data_for_image = data_for_image.reset_index(drop=True)

# %%
data_for_image
# Out:
#    item_name item_code
# 0          쌀       111
# 1         찹쌀       112
# 2          콩       141
# 3          팥       142
# 4         녹두       143
# 5        고구마       151
# 6         감자       152
# 7         배추       211
# 8        양배추       212
# 9        시금치       213
# 10        상추       214
# 11     얼갈이배추       215
# 12        수박       221
# 13        참외       222
# 14        오이       223
# 15        호박       224
# 16       토마토       225
# 17        딸기       226
# 18         무       231
# 19        당근       232
# 20        열무       233
# 21       건고추       241
# 22       풋고추       242
# 23      붉은고추       243
# 24        양파       245
# 25         파       246
# 26        생강       247
# 27      고춧가루       248
# 28       미나리       252
# 29        깻잎       253
# 30        피망       255
# 31      파프리카       256
# 32        멜론       257
# 33   깐마늘(국산)       258
# 34     방울토마토       422
# 35        참깨       312
# 36        땅콩       314
# 37     느타리버섯       315
# 38      팽이버섯       316
# 39     새송이버섯       317
# 40        호두       318
# 41       아몬드       319
# 42        사과       411
# 43         배       412
# 44       바나나       418
# 45       참다래       419
# 46      파인애플       420
# 47       오렌지       421
# 48        레몬       424
# 49       건포도       426
# 50     건블루베리       427
# 51        망고       428
# 52       쇠고기       512
# 53      돼지고기       514
# 54       닭고기       515
# 55        계란       516
# 56        우유       535
# 57       고등어       611
# 58        꽁치       612
# 59        갈치       613
# 60        명태       615
# 61      물오징어       619
# 62       건멸치       638
# 63      건오징어       640
# 64         김       641
# 65       건미역       642
# 66         굴       644
# 67      수입조기       649
# 68       새우젓       650
# 69      멸치액젓       651
# 70      굵은소금       652
# 71        전복       653
# 72        새우       654

# %%
data_for_image.to_excel("./all_data_for_image.xlsx")

# %%
pwd
# Out:
# '/Users/lana/Desktop/projects/42_cart_savior'
